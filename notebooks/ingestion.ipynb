# %%
import pandas as pd
from pathlib import Path

file_path = Path("C:/Users/gclou/Downloads/T_ONTIME_REPORTING_20260602_150320/T_ONTIME_REPORTING.csv")
df = pd.read_csv(file_path)

# %%
sample = df.head()
sample
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE OP_UNIQUE_CARRIER  \
# 0      1             1            7  1/1/2023 12:00:00 AM                9E
# 1      1             1            7  1/1/2023 12:00:00 AM                9E
# 2      1             1            7  1/1/2023 12:00:00 AM                9E
# 3      1             1            7  1/1/2023 12:00:00 AM                9E
# 4      1             1            7  1/1/2023 12:00:00 AM                9E
#
#   ORIGIN                ORIGIN_CITY_NAME DEST DEST_CITY_NAME  CRS_DEP_TIME  \
# 0    ABE  Allentown/Bethlehem/Easton, PA  ATL    Atlanta, GA           600
# 1    ABY                      Albany, GA  ATL    Atlanta, GA           736
# 2    ABY                      Albany, GA  ATL    Atlanta, GA          1255
# 3    AEX                  Alexandria, LA  ATL    Atlanta, GA          1150
# 4    AEX                  Alexandria, LA  ATL    Atlanta, GA          1748
#
#    ...  CRS_ARR_TIME  ARR_DELAY  CANCELLED  DIVERTED  DISTANCE  CARRIER_DELAY  \
# 0  ...           825       -9.0        0.0       0.0     692.0            NaN
# 1  ...           844        0.0        0.0       0.0     145.0            NaN
# 2  ...          1355      -11.0        0.0       0.0     145.0            NaN
# 3  ...          1433      427.0        0.0       0.0     500.0            0.0
# 4  ...          2037       72.0        0.0       0.0     500.0           11.0
#
#    WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 0            NaN        NaN             NaN                  NaN
# 1            NaN        NaN             NaN                  NaN
# 2            NaN        NaN             NaN                  NaN
# 3           83.0        2.0             0.0                342.0
# 4            0.0        0.0             0.0                 61.0
#
# [5 rows x 21 columns]

# %%
sample.to_csv("C:/Users/gclou/Documents/CloudComputing_DA/Flight-Delay-Prediction-Using-Apache-Spark/data/sample.csv", index=False)
