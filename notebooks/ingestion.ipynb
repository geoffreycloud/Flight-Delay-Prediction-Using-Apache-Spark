# %%
import pandas as pd
from pathlib import Path
import os

file_path = Path("C:/Users/gclou/Downloads/T_ONTIME_REPORTING_20260602_150320/T_ONTIME_REPORTING.csv")
df = pd.read_csv(file_path)

# %%
sample = df.loc[:2499]
sample
# Out:
#       MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 0         1             1            7  1/1/2023 12:00:00 AM
# 1         1             1            7  1/1/2023 12:00:00 AM
# 2         1             1            7  1/1/2023 12:00:00 AM
# 3         1             1            7  1/1/2023 12:00:00 AM
# 4         1             1            7  1/1/2023 12:00:00 AM
# ...     ...           ...          ...                   ...
# 2495      1             1            7  1/1/2023 12:00:00 AM
# 2496      1             1            7  1/1/2023 12:00:00 AM
# 2497      1             1            7  1/1/2023 12:00:00 AM
# 2498      1             1            7  1/1/2023 12:00:00 AM
# 2499      1             1            7  1/1/2023 12:00:00 AM
#
#      OP_UNIQUE_CARRIER ORIGIN                ORIGIN_CITY_NAME DEST  \
# 0                   9E    ABE  Allentown/Bethlehem/Easton, PA  ATL
# 1                   9E    ABY                      Albany, GA  ATL
# ...

# %%
# Save sample to CSV (2500 rows)
sample.to_csv("C:/Users/gclou/Documents/CloudComputing_DA/Flight-Delay-Prediction-Using-Apache-Spark/data/sample.csv", index=False)

# %%
import pandas as pd
import os

path = r"C:\Users\gclou\Documents\CloudComputing_DA\Flight-Delay-Prediction-Using-Apache-Spark\data\sample.csv"
df = pd.read_csv(path) # Will read from amazon s3 link in the final version

os.makedirs("../stream_input", exist_ok=True)

chunk_size = 500 # Will change to 50000 for actual use

for i, start in enumerate(range(0, len(df), chunk_size)):
    chunk = df.iloc[start:start + chunk_size]

    chunk.to_csv(
        f"../stream_input/flights_batch_{i}.csv",
        index=False
    )
